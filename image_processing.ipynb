# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import numpy as np

# %%
# creating a 'red' image of 256x256 pixels
red_img = Image.new('RGB', (256, 256), color='red')
red_img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
np.array(red_img)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        ...,
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]]], dtype=uint8)

# %%
circle = Image.new('RGBA', (256, 256), (0, 0, 0, 0))
draw = ImageDraw.Draw(circle)
draw.circle((128, 128), 64, fill='red')
draw.circle((128, 128), 50, fill='green')
circle
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256>

# %%
circle.save('my_circle.png')

# %%
img2 = Image.open(r"C:\Users\HP\Pictures\goku.jpg")
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=770x1201>

# %%
print("Image Properties")
print("Format: ", img2.format)
print("Mode: ", img2.mode)
print("Size", img2.size)
print("Width: ", img2.width)
print("Height: ", img2.height)
print("Palette: ", img2.palette)
print("Info: ", img2.info)
print("Filename: ", img2.filename)
# Out:
# Image Properties
# Format:  JPEG
# Mode:  RGB
# Size (770, 1201)
# Width:  770
# Height:  1201
# Palette:  None
# Info:  {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1), 'progressive': 1, 'progression': 1}
# Filename:  C:\Users\HP\Pictures\goku.jpg

# %% [markdown]
# image manipulation

# %%
img3 = img2.resize((256, 256))
img3
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img3.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img3.rotate(45, fillcolor='white')
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
img3.rotate(-45, fillcolor='white', expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=364x364>

# %%
img3.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# concatenating images
img4 = Image.new('RGB', (512, 512))
img4.paste(img3.rotate(45, fillcolor='white'), (0, 256))
img4.paste(img3.rotate(-45, fillcolor='white'), (256, 256))
img4.paste(img3.transpose(Image.Transpose.FLIP_LEFT_RIGHT), (256, 0))
img4.paste(img3, (0, 0))
img4.save('goku_collage.png')

# %%
# blending images
Image.blend(
    red_img,
    img3,
    alpha=0.5
)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
a = Image.open(r"C:\Users\HP\Pictures\goku.jpg")
b = Image.open(r"C:\Users\HP\Pictures\luffy.jpg")
print(a.size, b.size)
print(a.mode, b.mode)
c = Image.blend(a, b, alpha=0.4)
c.show()
# Out:
# (770, 1201) (189, 266)
# RGB RGB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       3 print(a.size, b.size)
#       4 print(a.mode, b.mode)
# ----> 5 c = Image.blend(a, b, alpha=0.4)
#       6 c.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:3540, in blend(im1, im2, alpha)
#    3538 im1.load()
#    3539 im2.load()
# -> 3540 return im1._new(core.blend(im1.im, im2.im, alpha))
#
# ValueError: images do not match

# %%
a.convert('RGBA') # convert to RGBA mode
# Out:
# <PIL.Image.Image image mode=RGBA size=770x1201>

# %%
d = Img3.new('RGB', (1024, 1024), 'blue')
Img3.blend(a, d, alpha=0.5).resize((256, 256))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 d = Img3.new('RGB', (1024, 1024), 'blue')
#       2 Img3.blend(a, d, alpha=0.5).resize((256, 256))
#
# NameError: name 'Img3' is not defined

# %%
# when sizes or mode mismatch
a = Image.open(r"C:\Users\ZAID\Pictures\goku.jpg")
b = Image.open(r"C:\Users\ZAID\Pictures\Picture5.png")
b = b.resize(a.size)
b = b.convert(a.mode)
print(a.size, b.size)
print(a.mode, b.mode)
Image.blend(a, b, alpha=0.5).resize((512, 512)).show()

# %% [markdown]
# filtering

# %%
a = a.resize((300,300))
blur = a.filter(ImageFilter.BLUR)
outline = a.filter(ImageFilter.CONTOUR)
emboss = a.filter(ImageFilter.EMBOSS)
light = a.filter(ImageFilter.MaxFilter())
dark = a.filter(ImageFilter.MinFilter())
sharpen = a.filter(ImageFilter.SHARPEN)
blur.show()
outline.show()
emboss.show()
light.show()
dark.show()
sharpen.show()

# %% [markdown]
# adding text to image

# %%
circle = Image.new('RGBA', (256, 256), (0, 0, 0, 0))
draw = ImageDraw.Draw(circle)
draw.circle((128, 128), 64, fill='red')
draw.circle((128, 128), 50, fill='green')
font = ImageFont.load_default(size=75)
draw.text((128, 128), 'Hi!', font=font, fill='white', anchor='mm')
circle.save('my_circle_2.png')
